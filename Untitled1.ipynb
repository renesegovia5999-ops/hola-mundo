# %% [markdown]
# <a href="https://colab.research.google.com/github/renesegovia5999-ops/hola-mundo/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #1
# **Introduccion**: Python
#
# Python es un lenguaje de programación de alto nivel, interpretado y de propósito general. Se caracteriza por su sintaxis sencilla y fácil de aprender, por lo que se utiliza en desarrollo web, inteligencia artificial, análisis de datos, automatización y desarrollo de aplicaciones.

# %%
print("¡Hola, mundo!")

# %% [markdown]
# #2
# **Introduccion**: C++
#
# C++ es un lenguaje de programación de propósito general, compilado y orientado a objetos. Destaca por su alto rendimiento y control sobre los recursos del sistema. Se utiliza para desarrollar videojuegos, sistemas operativos, aplicaciones de escritorio y software de alto desempeño.

# %%
#include <iostream>
using namespace std;

int main() {
    cout << "¡Hola, mundo!" << endl;
    return 0;
}

# %% [markdown]
# #3
# **Introduccion**: Java
#
# Java es un lenguaje de programación orientado a objetos y multiplataforma. Su principal ventaja es que los programas pueden ejecutarse en diferentes sistemas operativos sin necesidad de modificar el código. Se emplea en aplicaciones empresariales, aplicaciones móviles para Android y desarrollo de sistemas web.

# %%
public class HolaMundo {
    public static void main(String[] args) {
        System.out.println("¡Hola, mundo!");
    }
}
